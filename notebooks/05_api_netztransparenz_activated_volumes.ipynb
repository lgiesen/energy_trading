# %% [markdown]
# # Netztransparenz API – aFRR/mFRR Activated Volumes
#
# This notebook demonstrates the raw API calls for activated aFRR/mFRR and documents the response structure.
# It then inspects how to aggregate across TSOs and compute total activated volumes.

# %% [markdown]
# ## Columns of interest
# - afrr_activated_mw_pos
# - afrr_activated_mw_neg
# - mfrr_activated_mw_pos
# - mfrr_activated_mw_neg
# - activated_volume_pos_mw (afrr + mfrr)
# - activated_volume_neg_mw (afrr + mfrr)

# %%
import os
import io
import requests
import pandas as pd
import polars as pl
from datetime import datetime
from zoneinfo import ZoneInfo

# %% [markdown]
# ## Configuration
# Set a **short** window to inspect raw responses. Adjust if needed.

# %%
START_UTC = '2025-11-01T00:00:00Z'
END_UTC   = '2025-11-03T00:00:00Z'

# Use NETZTRANSPARENZ_TOKEN or client credentials
TOKEN = os.getenv('NETZTRANSPARENZ_TOKEN')
CLIENT_ID = os.getenv('NETZTRANSPARENZ_CLIENT_ID')
CLIENT_SECRET = os.getenv('NETZTRANSPARENZ_CLIENT_SECRET')

# %%
def _ensure_bearer(token: str) -> str:
    return token if token.startswith('Bearer ') else f'Bearer {token}'

def _fetch_token_from_client_credentials(client_id: str, client_secret: str) -> str:
    url = 'https://identity.netztransparenz.de/users/connect/token'
    payload = {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
    }
    headers = {'Content-Type': 'application/x-www-form-urlencoded'}
    resp = requests.post(url, data=payload, headers=headers, timeout=60)
    resp.raise_for_status()
    token = resp.json().get('access_token')
    if not token:
        raise RuntimeError('Token response missing access_token')
    return _ensure_bearer(token)

def get_token() -> str:
    if TOKEN:
        return _ensure_bearer(TOKEN)
    if CLIENT_ID and CLIENT_SECRET:
        return _fetch_token_from_client_credentials(CLIENT_ID, CLIENT_SECRET)
    raise RuntimeError('No token provided. Set NETZTRANSPARENZ_TOKEN or CLIENT_ID/CLIENT_SECRET.')

# %%
def to_berlin(ts_utc: str) -> str:
    dt = datetime.fromisoformat(ts_utc.replace('Z', '+00:00'))
    return dt.astimezone(ZoneInfo('Europe/Berlin')).strftime('%Y-%m-%dT%H:%M:%S')

def fetch_csv(url: str, token: str) -> str:
    resp = requests.get(url, headers={'Authorization': token}, timeout=60)
    resp.raise_for_status()
    return resp.text

def read_csv(text: str) -> pl.DataFrame:
    cleaned = text.lstrip('\ufeff').lstrip('ï»¿').replace('\r\n', '\n').replace('\r', '\n')
    return pl.read_csv(io.BytesIO(cleaned.encode('utf-8')), separator=';', infer_schema_length=2000, quote_char=None)

# %% [markdown]
# ## Raw API calls
# We fetch the aFRR and mFRR activated volumes for the same window.

# %%
token = get_token()
base = 'https://ds.netztransparenz.de/api/v1/data'

start_local = to_berlin(START_UTC)
end_local = to_berlin(END_UTC)

url_afrr = f"{base}/NrvSaldo/AktivierteSRL/Qualitaetsgesichert/{start_local}/{end_local}"
url_mfrr = f"{base}/NrvSaldo/AktivierteMRL/Qualitaetsgesichert/{start_local}/{end_local}"

afrr_raw = read_csv(fetch_csv(url_afrr, token))
mfrr_raw = read_csv(fetch_csv(url_mfrr, token))

afrr_raw.head()
# Out:
# shape: (5, 17)
# ┌────────────┬──────────┬───────┬───────┬───┬─────────────┬─────────────┬─────────────┬────────────┐
# │ Datum      ┆ Zeitzone ┆ von   ┆ bis   ┆ … ┆ Amprion     ┆ TenneT TSO  ┆ TransnetBW  ┆ Deutschlan │
# │ ---        ┆ ---      ┆ ---   ┆ ---   ┆   ┆ (Negativ)   ┆ (Negativ)   ┆ (Negativ)   ┆ d          │
# │ str        ┆ str      ┆ str   ┆ str   ┆   ┆ ---         ┆ ---         ┆ ---         ┆ (Negativ)  │
# │            ┆          ┆       ┆       ┆   ┆ str         ┆ str         ┆ str         ┆ ---        │
# │            ┆          ┆       ┆       ┆   ┆             ┆             ┆             ┆ str        │
# ╞════════════╪══════════╪═══════╪═══════╪═══╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 01.11.2025 ┆ UTC      ┆ 01:00 ┆ 01:15 ┆ … ┆ 0,000       ┆ 0,184       ┆ 0,060       ┆ 0,640      │
# │ 01.11.2025 ┆ UTC      ┆ 01:15 ┆ 01:30 ┆ … ┆ 0,000       ┆ 1,244       ┆ 0,460       ┆ 2,956      │
# │ 01.11.2025 ┆ UTC      ┆ 01:30 ┆ 01:45 ┆ … ┆ 0,000       ┆ 0,120       ┆ 0,036       ┆ 0,420      │
# │ 01.11.2025 ┆ UTC      ┆ 01:45 ┆ 02:00 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,024      │
# │ 01.11.2025 ┆ UTC      ┆ 02:00 ┆ 02:15 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,000      │
# └────────────┴──────────┴───────┴───────┴───┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
mfrr_raw.head()
# Out:
# shape: (5, 17)
# ┌────────────┬──────────┬───────┬───────┬───┬─────────────┬─────────────┬─────────────┬────────────┐
# │ Datum      ┆ Zeitzone ┆ von   ┆ bis   ┆ … ┆ Amprion     ┆ TenneT TSO  ┆ TransnetBW  ┆ Deutschlan │
# │ ---        ┆ ---      ┆ ---   ┆ ---   ┆   ┆ (Negativ)   ┆ (Negativ)   ┆ (Negativ)   ┆ d          │
# │ str        ┆ str      ┆ str   ┆ str   ┆   ┆ ---         ┆ ---         ┆ ---         ┆ (Negativ)  │
# │            ┆          ┆       ┆       ┆   ┆ str         ┆ str         ┆ str         ┆ ---        │
# │            ┆          ┆       ┆       ┆   ┆             ┆             ┆             ┆ str        │
# ╞════════════╪══════════╪═══════╪═══════╪═══╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 01.11.2025 ┆ UTC      ┆ 01:00 ┆ 01:15 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,000      │
# │ 01.11.2025 ┆ UTC      ┆ 01:15 ┆ 01:30 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,000      │
# │ 01.11.2025 ┆ UTC      ┆ 01:30 ┆ 01:45 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,000      │
# │ 01.11.2025 ┆ UTC      ┆ 01:45 ┆ 02:00 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,000      │
# │ 01.11.2025 ┆ UTC      ┆ 02:00 ┆ 02:15 ┆ … ┆ 0,000       ┆ 0,000       ┆ 0,000       ┆ 0,000      │
# └────────────┴──────────┴───────┴───────┴───┴─────────────┴─────────────┴─────────────┴────────────┘

# %% [markdown]
# ## Inspect response columns (TSO breakdown)
# We expect 4 TSO columns for POS/NEG each. The goal is to **sum** across TSOs per timestamp.

# %%
afrr_raw.columns
# Out:
# ['Datum',
#  'Zeitzone',
#  'von',
#  'bis',
#  'Datenkategorie',
#  'Datentyp',
#  'Einheit',
#  '50Hertz (Positiv)',
#  'Amprion (Positiv)',
#  'TenneT TSO (Positiv)',
#  'TransnetBW (Positiv)',
#  'Deutschland (Positiv)',
#  '50Hertz (Negativ)',
#  'Amprion (Negativ)',
#  'TenneT TSO (Negativ)',
#  'TransnetBW (Negativ)',
#  'Deutschland (Negativ)']

# %%
mfrr_raw.columns
# Out:
# ['Datum',
#  'Zeitzone',
#  'von',
#  'bis',
#  'Datenkategorie',
#  'Datentyp',
#  'Einheit',
#  '50Hertz (Positiv)',
#  'Amprion (Positiv)',
#  'TenneT TSO (Positiv)',
#  'TransnetBW (Positiv)',
#  'Deutschland (Positiv)',
#  '50Hertz (Negativ)',
#  'Amprion (Negativ)',
#  'TenneT TSO (Negativ)',
#  'TransnetBW (Negativ)',
#  'Deutschland (Negativ)']

# %% [markdown]
# ## Aggregation logic (sum across TSOs)
# We sum all columns containing 'positiv' for POS and 'negativ' for NEG, excluding meta columns.

# %%
def normalize_cols(df: pl.DataFrame) -> pl.DataFrame:
    mapping = {c: c.strip() for c in df.columns}
    df = df.rename(mapping)
    mapping_lower = {c: c.lower() for c in df.columns}
    return df.rename(mapping_lower)

def tidy_activation(df: pl.DataFrame, prefix: str) -> pl.DataFrame:
    df = normalize_cols(df)
    date_col = 'datum' if 'datum' in df.columns else df.columns[0]
    time_col = 'von' if 'von' in df.columns else df.columns[1]
    ts = (
        pl.concat_str([pl.col(date_col), pl.lit(' '), pl.col(time_col)])
        .str.to_datetime('%d.%m.%Y %H:%M', strict=False)
        .dt.replace_time_zone('UTC')
        .alias('timestamp_utc')
    )
    meta_cols = {date_col, time_col, 'zeitzone'}
    pos_cols = [c for c in df.columns if 'positiv' in c and c not in meta_cols]
    neg_cols = [c for c in df.columns if 'negativ' in c and c not in meta_cols]

    def clean_num(col: str) -> pl.Expr:
        return (
            pl.col(col)
            .cast(pl.Utf8)
            .str.replace('.', '')
            .str.replace(',', '.')
            .cast(pl.Float64, strict=False)
        )

    clean = df.with_columns([ts] + [clean_num(c).alias(c) for c in (pos_cols + neg_cols)])
    clean = clean.with_columns(
        pl.sum_horizontal([pl.col(c) for c in pos_cols]).alias(f'{prefix}_pos'),
        pl.sum_horizontal([pl.col(c) for c in neg_cols]).alias(f'{prefix}_neg'),
    ).select(['timestamp_utc', f'{prefix}_pos', f'{prefix}_neg'])
    return clean.group_by('timestamp_utc').agg(
        pl.col(f'{prefix}_pos').sum(),
        pl.col(f'{prefix}_neg').sum(),
    ).sort('timestamp_utc')

afrr = tidy_activation(afrr_raw, 'afrr_activated_mw')
mfrr = tidy_activation(mfrr_raw, 'mfrr_activated_mw')

afrr.head()
# Out:
# shape: (5, 3)
# ┌─────────────────────────┬───────────────────────┬───────────────────────┐
# │ timestamp_utc           ┆ afrr_activated_mw_pos ┆ afrr_activated_mw_neg │
# │ ---                     ┆ ---                   ┆ ---                   │
# │ datetime[μs, UTC]       ┆ f64                   ┆ f64                   │
# ╞═════════════════════════╪═══════════════════════╪═══════════════════════╡
# │ 2025-11-01 01:00:00 UTC ┆ 15.4                  ┆ 1.28                  │
# │ 2025-11-01 01:15:00 UTC ┆ 1.84                  ┆ 1.912                 │
# │ 2025-11-01 01:30:00 UTC ┆ 16.552                ┆ 0.84                  │
# │ 2025-11-01 01:45:00 UTC ┆ 26.784                ┆ 0.048                 │
# │ 2025-11-01 02:00:00 UTC ┆ 52.016                ┆ 0.0                   │
# └─────────────────────────┴───────────────────────┴───────────────────────┘

# %%
mfrr.head()
# Out:
# shape: (5, 3)
# ┌─────────────────────────┬───────────────────────┬───────────────────────┐
# │ timestamp_utc           ┆ mfrr_activated_mw_pos ┆ mfrr_activated_mw_neg │
# │ ---                     ┆ ---                   ┆ ---                   │
# │ datetime[μs, UTC]       ┆ f64                   ┆ f64                   │
# ╞═════════════════════════╪═══════════════════════╪═══════════════════════╡
# │ 2025-11-01 01:00:00 UTC ┆ 0.0                   ┆ 0.0                   │
# │ 2025-11-01 01:15:00 UTC ┆ 0.0                   ┆ 0.0                   │
# │ 2025-11-01 01:30:00 UTC ┆ 0.0                   ┆ 0.0                   │
# │ 2025-11-01 01:45:00 UTC ┆ 0.0                   ┆ 0.0                   │
# │ 2025-11-01 02:00:00 UTC ┆ 0.0                   ┆ 0.0                   │
# └─────────────────────────┴───────────────────────┴───────────────────────┘

# %% [markdown]
# ## Total activated volume (aFRR + mFRR)
# We fill missing mFRR values with 0.0 before summation.

# %%
total = afrr.join(mfrr, on='timestamp_utc', how='full')
total = total.with_columns(
    (pl.col('afrr_activated_mw_pos') + pl.col('mfrr_activated_mw_pos').fill_null(0.0)).alias('activated_volume_pos_mw'),
    (pl.col('afrr_activated_mw_neg') + pl.col('mfrr_activated_mw_neg').fill_null(0.0)).alias('activated_volume_neg_mw'),
)
total.head()
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp_ ┆ afrr_activ ┆ afrr_activ ┆ timestamp ┆ mfrr_acti ┆ mfrr_acti ┆ activated ┆ activated │
# │ utc        ┆ ated_mw_po ┆ ated_mw_ne ┆ _utc_righ ┆ vated_mw_ ┆ vated_mw_ ┆ _volume_p ┆ _volume_n │
# │ ---        ┆ s          ┆ g          ┆ t         ┆ pos       ┆ neg       ┆ os_mw     ┆ eg_mw     │
# │ datetime[μ ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ s, UTC]    ┆ f64        ┆ f64        ┆ datetime[ ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# │            ┆            ┆            ┆ μs, UTC]  ┆           ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-11-01 ┆ 15.4       ┆ 1.28       ┆ 2025-11-0 ┆ 0.0       ┆ 0.0       ┆ 15.4      ┆ 1.28      │
# │ 01:00:00   ┆            ┆            ┆ 1         ┆           ┆           ┆           ┆           │
# │ UTC        ┆            ┆            ┆ 01:00:00  ┆           ┆           ┆           ┆           │
# │            ┆            ┆            ┆ UTC       ┆           ┆           ┆           ┆           │
# │ 2025-11-01 ┆ 1.84       ┆ 1.912      ┆ 2025-11-0 ┆ 0.0       ┆ 0.0       ┆ 1.84      ┆ 1.912     │
# │ 01:15:00   ┆            ┆            ┆ 1         ┆           ┆           ┆           ┆           │
# │ UTC        ┆            ┆            ┆ 01:15:00  ┆           ┆           ┆           ┆           │
# │            ┆            ┆            ┆ UTC       ┆           ┆           ┆           ┆           │
# │ 2025-11-01 ┆ 16.552     ┆ 0.84       ┆ 2025-11-0 ┆ 0.0       ┆ 0.0       ┆ 16.552    ┆ 0.84      │
# │ 01:30:00   ┆            ┆            ┆ 1         ┆           ┆           ┆           ┆           │
# │ UTC        ┆            ┆            ┆ 01:30:00  ┆           ┆           ┆           ┆           │
# │            ┆            ┆            ┆ UTC       ┆           ┆           ┆           ┆           │
# │ 2025-11-01 ┆ 26.784     ┆ 0.048      ┆ 2025-11-0 ┆ 0.0       ┆ 0.0       ┆ 26.784    ┆ 0.048     │
# │ 01:45:00   ┆            ┆            ┆ 1         ┆           ┆           ┆           ┆           │
# │ UTC        ┆            ┆            ┆ 01:45:00  ┆           ┆           ┆           ┆           │
# │            ┆            ┆            ┆ UTC       ┆           ┆           ┆           ┆           │
# │ 2025-11-01 ┆ 52.016     ┆ 0.0        ┆ 2025-11-0 ┆ 0.0       ┆ 0.0       ┆ 52.016    ┆ 0.0       │
# │ 02:00:00   ┆            ┆            ┆ 1         ┆           ┆           ┆           ┆           │
# │ UTC        ┆            ┆            ┆ 02:00:00  ┆           ┆           ┆           ┆           │
# │            ┆            ┆            ┆ UTC       ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Data quality quick check
# Nulls and zeros for the derived columns.

# %%
for col in ['afrr_activated_mw_pos','afrr_activated_mw_neg','mfrr_activated_mw_pos','mfrr_activated_mw_neg','activated_volume_pos_mw','activated_volume_neg_mw']:
    if col in total.columns:
        stats = total.select(
            pl.col(col).is_null().sum().alias('nulls'),
            (pl.col(col) == 0).sum().alias('zeros'),
            pl.col(col).min().alias('min'),
            pl.col(col).max().alias('max'),
            pl.col(col).mean().alias('mean'),
        ).to_dicts()[0]
        print(col, stats)
# Out:
# afrr_activated_mw_pos {'nulls': 0, 'zeros': 50, 'min': 0.0, 'max': 252.272, 'mean': 26.301041666666663}
# afrr_activated_mw_neg {'nulls': 0, 'zeros': 74, 'min': 0.0, 'max': 173.48, 'mean': 16.897916666666667}
# mfrr_activated_mw_pos {'nulls': 0, 'zeros': 192, 'min': 0.0, 'max': 0.0, 'mean': 0.0}
# mfrr_activated_mw_neg {'nulls': 0, 'zeros': 192, 'min': 0.0, 'max': 0.0, 'mean': 0.0}
# activated_volume_pos_mw {'nulls': 0, 'zeros': 50, 'min': 0.0, 'max': 252.272, 'mean': 26.301041666666663}
# activated_volume_neg_mw {'nulls': 0, 'zeros': 74, 'min': 0.0, 'max': 173.48, 'mean': 16.897916666666667}

# %% [markdown]
# ##### Verify summation logic (TSO sum ≈ Germany total)

# %%
import polars as pl
import plotly.express as px

# Load a clean period with data (e.g. 2023)
df = pl.read_parquet("../data/raw/netztransparenz.parquet")

cols = ["timestamp_utc", "rz_saldo_mw", "50hertz", "amprion", "tennet tso", "transnetbw"]
missing = [c for c in cols if c not in df.columns]
if missing:
    raise KeyError(f"Missing columns: {missing}")

sample = (
    df.select(cols)
      .filter(pl.col("timestamp_utc").is_between(
          pl.datetime(2023,1,1, time_zone="UTC"),
          pl.datetime(2023,2,1, time_zone="UTC"))
      )
      .drop_nulls()
)

sample = sample.with_columns(
    (pl.col("50hertz") + pl.col("amprion") + pl.col("tennet tso") + pl.col("transnetbw")).alias("calc_sum")
)

corr = sample.select(pl.corr("rz_saldo_mw", "calc_sum")).item()
print("Correlation (rz_saldo_mw vs TSO sum):", corr)

# scatter plot
fig = px.scatter(sample.to_pandas(), x="calc_sum", y="rz_saldo_mw", title="TSO sum vs Germany total")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 10
#       8 missing = [c for c in cols if c not in df.columns]
#       9 if missing:
# ---> 10     raise KeyError(f"Missing columns: {missing}")
#      12 sample = (
#      13     df.select(cols)
#      14       .filter(pl.col("timestamp_utc").is_between(
#    (...)     18       .drop_nulls()
#      19 )
#      21 sample = sample.with_columns(
#      22     (pl.col("50hertz") + pl.col("amprion") + pl.col("tennet tso") + pl.col("transnetbw")).alias("calc_sum")
#      23 )
#
# KeyError: "Missing columns: ['50hertz', 'amprion', 'tennet tso', 'transnetbw']"

# %% [markdown]
# ##### Investigate “Betrieblich” (Operational) structure + sign logic

# %%
import requests
import io
import polars as pl

base_url = "https://ds.netztransparenz.de/api/v1/data"
start = "2023-01-01T00:00Z"
end = "2023-01-07T00:00Z"

# Try Betrieblich
url = f"{base_url}/NrvSaldo/RZSaldo/Betrieblich/{start}/{end}"
resp = requests.get(url, timeout=60)
resp.raise_for_status()
text = resp.text

df_op = pl.read_csv(io.BytesIO(text.encode("utf-8")), separator=";")
print(df_op.columns)
print(df_op.head(3))

# If there are Pos/Neg columns, test net = pos - neg
pos_cols = [c for c in df_op.columns if "Positiv" in c]
neg_cols = [c for c in df_op.columns if "Negativ" in c]

if pos_cols and neg_cols:
    df_op = df_op.with_columns(
        pl.sum_horizontal([pl.col(c).cast(pl.Utf8).str.replace(",", ".").cast(pl.Float64) for c in pos_cols]).alias("pos_sum"),
        pl.sum_horizontal([pl.col(c).cast(pl.Utf8).str.replace(",", ".").cast(pl.Float64) for c in neg_cols]).alias("neg_sum"),
    )
    df_op = df_op.with_columns((pl.col("pos_sum") - pl.col("neg_sum")).alias("net_calc"))
    print(df_op.select(["pos_sum","neg_sum","net_calc"]).head(5))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 12
#      10 url = f"{base_url}/NrvSaldo/RZSaldo/Betrieblich/{start}/{end}"
#      11 resp = requests.get(url, timeout=60)
# ---> 12 resp.raise_for_status()
#      13 text = resp.text
#      15 df_op = pl.read_csv(io.BytesIO(text.encode("utf-8")), separator=";")
#
# File ~/Code/energyTrading/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://ds.netztransparenz.de/api/v1/data/NrvSaldo/RZSaldo/Betrieblich/2023-01-01T00:00Z/2023-01-07T00:00Z

# %%
import io
import os
import requests
import polars as pl

# Fetch raw RZSaldo directly so we can see TSO columns (50Hertz/Amprion/TenneT/TransnetBW)
base_url = "https://ds.netztransparenz.de/api/v1/data"
start = "2023-01-01T00:00Z"
end = "2023-01-07T00:00Z"
url = f"{base_url}/NrvSaldo/RZSaldo/Qualitaetsgesichert/{start}/{end}"

# Token handling (same as fetch_netztransparenz.py)
token = os.getenv("NETZTRANSPARENZ_TOKEN")
if not token:
    raise RuntimeError("Set NETZTRANSPARENZ_TOKEN before running this cell")

headers = {"Authorization": token if token.startswith("Bearer ") else f"Bearer {token}"}
resp = requests.get(url, headers=headers, timeout=60)
resp.raise_for_status()

raw = resp.text.lstrip("﻿").lstrip("ï»¿")
rz_raw = pl.read_csv(io.BytesIO(raw.encode("utf-8")), separator=";", infer_schema_length=2000)
print(rz_raw.columns)
rz_raw.head(3)
